# %% [markdown]
# using relationship
# y = 4x1 + 5x2 + 10x3 + 6x4 + 2x5 + 4X6
#
# where : X1 = asset_base,
#         X2 = bda_capability,
#         X3 = predictive_analytics_usage,
#         X4 = descriptive_analytics_usage,
#         X5 = diagnostic_analytics_usage,
#         X6 = prescriptive_analytics_usage,
#         y  = revenue_growth
#
#
# also columns should be with values in range 1 to 5 expect for the revenue_growth which should be from 0 to 100% but should be 15% at most.
#
# deisgn an algorithim to genarate a data set with columns "asset_base, bda_capability, predictive_analytics_usage, descriptive_analytics_usage, diagnostic_analytics_usage, prescriptive_analytics_usage, revenue_growth" and 67 rows satisfying the relationship mentioned above using python

# %%
import numpy as np
import pandas as pd

X, y = make_regression(n_samples=67, n_features=6, n_informative=6, n_targets=1,
                       noise=0.0, random_state=42)

X_scaled = (X - np.min(X, axis=0)) / (np.max(X, axis=0) - np.min(X, axis=0)) * 4 + 1

y_scaled = y / np.max(y) * 0.15

df = pd.DataFrame(np.column_stack((X_scaled[:,0], X_scaled[:,1], X_scaled[:,2], 
                                    X_scaled[:,3], X_scaled[:,4], X_scaled[:,5], y_scaled)),
                  columns=['asset_base', 'bda_capability', 'predictive_analytics_usage', 
                           'descriptive_analytics_usage', 'diagnostic_analytics_usage', 
                           'prescriptive_analytics_usage', 'revenue_growth'])

df.head()
# Out:
#    asset_base  bda_capability  predictive_analytics_usage  \
# 0    2.607141        2.697300                    2.855230
# 1    3.627134        3.576497                    1.343808
# 2    3.541565        2.450647                    1.909712
# 3    3.277362        2.231973                    2.985404
# 4    2.799997        4.177464                    3.459066
#
#    descriptive_analytics_usage  diagnostic_analytics_usage  \
# 0                     4.079512                    3.051258
# 1                     2.093527                    3.704367
# 2                     2.735676                    2.741598
# 3                     3.083584                    3.351203
# 4                     1.390487                    3.379835
#
#    prescriptive_analytics_usage  revenue_growth
# 0                      1.282343       -0.054865
# 1                      5.000000        0.117542
# 2                      2.476191       -0.053888
# 3                      2.654031       -0.016075
# 4                      1.552112       -0.051664

# %%
X = df[['asset_base', 'bda_capability', 'predictive_analytics_usage', 
                           'descriptive_analytics_usage', 'diagnostic_analytics_usage', 
                           'prescriptive_analytics_usage']]
y = df['revenue_growth']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
r_squared = model.rsquared
print(r_squared)
# Out:
# 1.0

# %%
df[['asset_base', 'bda_capability', 'predictive_analytics_usage', 
                           'descriptive_analytics_usage', 'diagnostic_analytics_usage', 
                           'prescriptive_analytics_usage']] = df[['asset_base', 'bda_capability', 'predictive_analytics_usage', 
                           'descriptive_analytics_usage', 'diagnostic_analytics_usage', 
                           'prescriptive_analytics_usage']].round(0)

# %%
df.head()
# Out:
#    asset_base  bda_capability  predictive_analytics_usage  \
# 0         3.0             3.0                         3.0
# 1         4.0             4.0                         1.0
# 2         4.0             2.0                         2.0
# 3         3.0             2.0                         3.0
# 4         3.0             4.0                         3.0
#
#    descriptive_analytics_usage  diagnostic_analytics_usage  \
# 0                          4.0                         3.0
# 1                          2.0                         4.0
# 2                          3.0                         3.0
# 3                          3.0                         3.0
# 4                          1.0                         3.0
#
#    prescriptive_analytics_usage  revenue_growth
# 0                           1.0       -0.054865
# 1                           5.0        0.117542
# 2                           2.0       -0.053888
# 3                           3.0       -0.016075
# 4                           2.0       -0.051664

# %%
df['revenue_growth'] = df['revenue_growth'].round(3)

# %%
df.head(5)
# Out:
#    asset_base  bda_capability  predictive_analytics_usage  \
# 0         3.0             3.0                         3.0
# 1         4.0             4.0                         1.0
# 2         4.0             2.0                         2.0
# 3         3.0             2.0                         3.0
# 4         3.0             4.0                         3.0
#
#    descriptive_analytics_usage  diagnostic_analytics_usage  \
# 0                          4.0                         3.0
# 1                          2.0                         4.0
# 2                          3.0                         3.0
# 3                          3.0                         3.0
# 4                          1.0                         3.0
#
#    prescriptive_analytics_usage  revenue_growth
# 0                           1.0          -0.055
# 1                           5.0           0.118
# 2                           2.0          -0.054
# 3                           3.0          -0.016
# 4                           2.0          -0.052

# %%
X = df[['asset_base', 'bda_capability', 'predictive_analytics_usage', 
                           'descriptive_analytics_usage', 'diagnostic_analytics_usage', 
                           'prescriptive_analytics_usage']]
y = df['revenue_growth']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
r_squared = model.rsquared
print(r_squared)
# Out:
# 0.9114809702358175

# %%
df.to_excel('df.xlsx')

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         revenue_growth   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     103.0
# Date:                Thu, 18 May 2023   Prob (F-statistic):           1.07e-29
# Time:                        12:14:56   Log-Likelihood:                 159.67
# No. Observations:                  67   AIC:                            -305.3
# Df Residuals:                      60   BIC:                            -289.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           -0.5690      0.027    -21.347      0.000      -0.622      -0.516
# asset_base                       0.0397      0.003     11.934      0.000       0.033       0.046
# bda_capability                   0.0373      0.003     11.759      0.000       0.031       0.044
# predictive_analytics_usage      -0.0006      0.003     -0.166      0.869      -0.008       0.006
# descriptive_analytics_usage      0.0315      0.003     10.552      0.000       0.026       0.037
# diagnostic_analytics_usage       0.0536      0.004     14.096      0.000       0.046       0.061
# prescriptive_analytics_usage     0.0261      0.004      6.952      0.000       0.019       0.034
# ==============================================================================
# Omnibus:                        4.930   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.085   Jarque-Bera (JB):                3.568
# Skew:                          -0.422   Prob(JB):                        0.168
# Kurtosis:                       2.248   Cond. No.                         68.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
